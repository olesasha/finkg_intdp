# %%
import re
import pandas as pd
import dotenv
import os
from neo4j import GraphDatabase

# %%
triplets_df_path = "../data/gfmag_sustainable_triplets.csv"
NEO4J_ENV = "../Neo4j-6b4d3211-Created-2026-01-22.txt"

# %%
triplets_df = pd.read_csv(triplets_df_path)

# %%
tester_df = triplets_df.head(10)

# %%
tester_df
# Out:
#             entity1        entity1_type             rel_type  \
# 0             Solar             product  has_positive_impact
# 1              Wind             product  has_positive_impact
# 2             China             country         is_member_of
# 3             India             country         is_member_of
# 4  Renewable energy  economic_indicator     is_competitor_of
# 5             Solar             product  has_positive_impact
# 6           Tunisia             country         has_exposure
# 7           Tunisia             country         has_exposure
# 8           Tunisia             country         has_exposure
# 9           Tunisia             country         has_exposure
#
#                     entity2          entity2_type               industry  \
# 0          Renewable energy    economic_indicator                 Energy
# 1          Renewable energy    economic_indicator                 Energy
# 2          Renewable energy    economic_indicator                 Energy
# 3          Renewable energy    economic_indicator                 Energy
# 4                      Coal    economic_indicator                 Energy
# 5        Electricity demand    economic_indicator                 Energy
# 6           New legislation                 event     Economic Indicator
# 7  Middle East developments                 event     Economic Indicator
# 8            War in Ukraine                 event     Economic Indicator
# 9          Instant payments  financial_instrument  Financial Institution
#
#                                                  url  \
# 0  https://gfmag.com/sustainable-finance/coal-tak...
# 1  https://gfmag.com/sustainable-finance/coal-tak...
# 2  https://gfmag.com/sustainable-finance/coal-tak...
# 3  https://gfmag.com/sustainable-finance/coal-tak...
# 4  https://gfmag.com/sustainable-finance/coal-tak...
# 5  https://gfmag.com/sustainable-finance/coal-tak...
# 6  https://gfmag.com/executive-interviews/biat-ce...
# 7  https://gfmag.com/executive-interviews/biat-ce...
# 8  https://gfmag.com/executive-interviews/biat-ce...
# 9  https://gfmag.com/executive-interviews/biat-ce...
#
#                         date
# 0  2025-11-09T09:30:00+00:00
# 1  2025-11-09T09:30:00+00:00
# 2  2025-11-09T09:30:00+00:00
# 3  2025-11-09T09:30:00+00:00
# 4  2025-11-09T09:30:00+00:00
# 5  2025-11-09T09:30:00+00:00
# 6  2025-11-07T10:16:56+00:00
# 7  2025-11-07T10:16:56+00:00
# 8  2025-11-07T10:16:56+00:00
# 9  2025-11-07T10:16:56+00:00

# %%
import os
import dotenv
from neo4j import GraphDatabase

def load_to_neo4j(df, env_file: str, batch_size: int = 1000):
    # load Aura credentials
    dotenv.load_dotenv(env_file)
    URI = os.getenv("NEO4J_URI")
    USER = os.getenv("NEO4J_USERNAME")
    PWD = os.getenv("NEO4J_PASSWORD")

    driver = GraphDatabase.driver(URI, auth=(USER, PWD))

    # batch insert function
    def batch_insert(tx, batch):
        for row in batch:
            rel_type = row['rel_type'].replace('`', '')  # sanitize
            query = f"""
            MERGE (e1:Entity {{name: $e1_name, type: $e1_type}})
            MERGE (e2:Entity {{name: $e2_name, type: $e2_type}})
            MERGE (e1)-[r:`{rel_type}`]->(e2)
            SET r.sector = $sector,
                r.url = $url,
                r.date = $date
            """
            tx.run(query,
                   e1_name=row['entity1'],
                   e1_type=row['entity1_type'],
                   e2_name=row['entity2'],
                   e2_type=row['entity2_type'],
                   sector=row['sector'],
                   url=row['url'],
                   date=str(row['date'])
            )


    # main session loop
    with driver.session() as session:
        batch = []
        for _, row in df.iterrows():
            batch.append({
                'entity1': row['entity1'],
                'entity1_type': row['entity1_type'],
                'entity2': row['entity2'],
                'entity2_type': row['entity2_type'],
                'rel_type': row['rel_type'],
                'sector': row['sector'],
                'url': row['url'],
                'date': row['date'],
            })
            if len(batch) == batch_size:
                session.execute_write(batch_insert, batch)
                batch = []
        if batch:
            session.execute_write(batch_insert, batch)

    driver.close()
    print("Graph data loaded to Neo4j successfully.")

# %%
load_to_neo4j(df=tester_df, env_file=NEO4J_ENV)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 load_to_neo4j(df=tester_df, env_file=NEO4J_ENV)
#
# Cell In[13], line 54, in load_to_neo4j(df, env_file, batch_size)
#      52             batch = []
#      53     if batch:
# ---> 54         session.execute_write(batch_insert, batch)
#      56 driver.close()
#      57 print("Graph data loaded to Neo4j successfully.")
#
# File ~/.local/lib/python3.9/site-packages/neo4j/_sync/work/session.py:808, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     755 @NonConcurrentMethodChecker._non_concurrent_method
#     756 def execute_write(
#     757     self,
#    (...)
#     762     **kwargs: _P.kwargs,
#     763 ) -> _R:
#     764     """
#     765     Execute a unit of work in a managed write transaction.
#     766
#    (...)
#     806     .. versionadded:: 5.0
#     807     """  # noqa: E501 example code isn't too long
# --> 808     return self._run_transaction(
#     809         WRITE_ACCESS,
#     810         TelemetryAPI.TX_FUNC,
#     811         transaction_function,
#     812         args,
#     813         kwargs,
#     814     )
#
# File ~/.local/lib/python3.9/site-packages/neo4j/_sync/work/session.py:588, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     586 tx = self._transaction
#     587 try:
# --> 588     result = transaction_function(tx, *args, **kwargs)
#     589 except asyncio.CancelledError:
#     590     # if cancellation callback has not been called yet:
#     591     if self._transaction is not None:
#
# Cell In[13], line 31, in load_to_neo4j.<locals>.batch_insert(tx, batch)
#      17 rel_type = row['rel_type'].replace('`', '')  # sanitize
#      18 query = f"""
#      19 MERGE (e1:Entity {{name: $e1_name, type: $e1_type}})
#      20 MERGE (e2:Entity {{name: $e2_name, type: $e2_type}})
#    (...)
#      24     r.date = $date
#      25 """
#      26 tx.run(query,
#      27        e1_name=row['entity1'],
#      28        e1_type=row['entity1_type'],
#      29        e2_name=row['entity2'],
#      30        e2_type=row['entity2_type'],
# ---> 31        sector=row['indsutry'],
#      32        url=row['url'],
#      33        date=str(row['date'])  # ensure string
#      34        )
#
# KeyError: 'indsutry'
